# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
abortion_stats = pd.read_csv("abortion_stats.csv")

abortion_nums = abortion_stats[51:]
abortion_rates = abortion_stats[0:51]

#abortion_nums = abortion_nums.sort_values("datum")
#abortion_rates = abortion_rates.sort_values("datum")

state_by_num = abortion_nums["state_id"]
state_by_rate = abortion_rates["state_id"]
abortion_rate = abortion_rates["datum"]
abortion_num =abortion_nums["datum"]

# %%
plt.figure(figsize = (20,7))
plt.bar(state_by_num, abortion_num,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Numbers in All 50 States')
plt.xlabel('State ID')
plt.ylabel('Number of Abortions')
plt.show()

# %%
plt.figure(figsize = (20,7))
plt.bar(state_by_rate,abortion_rate,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in All 50 States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
pacific_region_ids = ["AK", "CA", "WA", "OR", "HI"]
pacific_region_nums = [8.6, 16.4, 12.1, 11.9, 12]
avg_pacific_num = 12.2

plt.figure(figsize = (20,7))
plt.bar(pacific_region_ids, pacific_region_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Pacific Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
rocky_mountain_region_ids = ["NV", "ID", "CO", "MT", "UT", "WY"]
rocky_mountain_region_nums = [16.4, 3.9, 10.9, 8.3, 4.4, 1.3]
avg_rocky_mountain_num = 7.53

plt.figure(figsize = (20,7))
plt.bar(rocky_mountain_region_ids, rocky_mountain_region_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Rocky Mountain Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
southwest_region_ids = ["TX", "AZ", "NM", "OK"]
southwest_region_nums = [9.4, 9.2, 11.7, 6.2]
avg_southwest_num = 9.125

plt.figure(figsize = (20,7))
plt.bar(southwest_region_ids, southwest_region_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Southwest Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
southeast_region_ids = ["AR", "MS", "KY", "LA", "TN", "WV", "VA", "SC", "FL", "NC", "AL", "GA"]
southeast_region_nums = [5.5, 4.3, 3.8, 10.6, 9.2, 4.4, 10.2, 5.3, 18.6, 14.6, 6.4, 16.9]
avg_southeast_num = 9.15

plt.figure(figsize = (20,7))
plt.bar(southeast_region_ids, southeast_region_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Southeast Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
midwest_region_ids = ["ND", "SD", "NE", "MN", "IA", "MO", "WI", "IL", "IN", "OH"]
midwest_region_nums = [7.9, 3.1, 5.5, 10.1, 6.3, 4, 5.9, 16.6, 5.9, 9.4]
avg_midwest_num = 7.47

plt.figure(figsize = (20,7))
plt.bar(midwest_region_ids, midwest_region_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Midwest Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
northeast_region_ids = ["ME", "MD", "MA", "CT", "DE", "NH", "NJ", "NY", "PA", "RI", "VT"]
northeast_region_nums = [8.8, 25, 13.5, 17.7, 10.5, 9.2, 28, 26.3, 13.1, 16.7, 11.4]
avg_northeast_num = 16.38

plt.figure(figsize = (20,7))
plt.bar(northeast_region_ids, northeast_region_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Northeast Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
region_ids = ["Pacific", "Rocky Mountain", "Southwest", "Southeast", "Midwest", "Northeast"]
region_abortion_nums = [avg_pacific_num, avg_rocky_mountain_num, avg_southwest_num, avg_southeast_num, avg_midwest_num, avg_northeast_num]

# %%
plt.figure(figsize = (20,7))
plt.bar(region_ids, region_abortion_nums,  width=0.5, align='center')
#plt.figure(figsize = (40,30))
plt.title('Abortion Rates in the Northeast Region States')
plt.xlabel('State ID')
plt.ylabel('Rates of Abortions')
plt.show()

# %%
contraceptives_data = pd.read_csv("contraception_data.csv")

# %%
contraceptives_data.dropna(subset = ["datum"])

abortions_averted = contraceptives_data[0:51].copy()

pregnancies_averted = contraceptives_data[103:153]

abortions_averted["datum"] = abortions_averted["datum"].apply(pd.to_numeric)

abortions_averted_state = abortions_averted["state_id"]
abortions_averted_rate = abortions_averted["datum"]

pregnancies_averted_state = pregnancies_averted["state_id"]
pregnancies_averted_rate = pregnancies_averted["datum"]

# %%
plt.figure(figsize = (20,7))
plt.bar(abortions_averted_state, abortions_averted_rate,  width=0.5, align='center')
plt.title('Abortions Averted Using Contraceptives in all 50 states')
plt.xlabel('State ID')
plt.ylabel('Number of Abortions Averted')
plt.show()

# %%
plt.figure(figsize = (20,7))
plt.bar(pregnancies_averted_state, pregnancies_averted_rate,  width=0.5, align='center')
plt.title('Pregnancies Averted Using Contraceptives in all 50 states')
plt.xlabel('State ID')
plt.ylabel('Number of Abortions Averted')
plt.show()

# %%
# Y = abortions_averted_rate  # response
# X = abortion_num  # predictor

# X = sm.add_constant(X)

# x, y = np.array(X), np.array(Y)

# plt.figure()

# model = LinearRegression().fit(x, y)
# Out:
# LinearRegression()

# %%
# Y = abortions_averted_rate  # response
# X = abortion_num  # predictor
plt.figure(figsize = (20,7))

X = np.arange(4)

plt.bar(pregnancies_averted_state, pregnancies_averted_rate, label = "Averted Pregnancies")
plt.bar(state_by_num, abortion_num, label = "Abortions")

plt.title('Pregnancies Averted Using Contraceptives Vs Abortion Rates in all 50 states')
plt.xlabel('State ID')
plt.ylabel('Numbers of Averted Pregnancies or Abortion rates')

plt.legend()
plt.show()
